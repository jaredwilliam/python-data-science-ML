# %% [markdown]
# # Bias Variance Trade-Off

# %% [markdown]
# Used to evaluate a model's performance.
#
# The bias variance trade off is the point where we are just adding noise by adding model complexity (flexibility).
#
# The training error goes down as it has to, but the test error is starting to go up.
#
# The model after the bias trade-off begins to overfit.

# %% [markdown]
# Imagine that the center of the targer is a model that perfectly predicts the correct values.
#
# As we move away from the center, our predictions get worse.

# %%
from IPython.display import Image

# %%
Image(filename='target.png')

# %% [markdown]
# Imagine we can repeat our entire model building process to get a number of separate hits on the target.
#
# Each hit represents an individual realization of our model, given the chance variability in the training data we gather.
#
# Sometimes we will get a good distribution of training data so we predict very well and we are close to the center, while sometimes our training data might be full of outliers or non-standard values resulting in poorer predictions.
#
# These different realizations result in a scatter of hits on the target.
#
# We are aiming for something that is Low Bias and Low Variance, but realistically, we are trading these two off.

# %% [markdown]
# A common temptation for beginners is to continually add complexity to a model until it fits the training set very well.

# %%
Image(filename='overfit.png')

# %% [markdown]
# Adding complexity can cause a model to overfit to your training data and cause large errors on new data, such as the test set.

# %%
Image(filename='modelflexibility.png')

# %% [markdown]
# Notice that the test data error increases with the more complicated model.

# %%
Image(filename='modelcomplexity.png')

# %% [markdown]
# We want our model's complexity to fall at the bias trade-off line.
