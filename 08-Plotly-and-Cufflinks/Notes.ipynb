# %%
# Plotly is an interactive visualization library
# Cufflinks connects plotly and pandas

# %%
import pandas as pd
import numpy as np
import chart_studio.plotly as py
import cufflinks as cf
from plotly.offline import download_plotlyjs,init_notebook_mode, plot,iplot
# %matplotlib inline

# %%
# This is going to connect javascript to the notebook
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# This allows you to run cufflinks offline
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# 2.Possible Colorscale Error 2: 
# In the "Real Data US Map Choropleth", 
# when you are creating the data dictionary, 
# make sure the colorscale line is = 'ylorbr', not 'YIOrbr'... so like this:
# colorscale='ylorbr'

# 3.Possible projection Error 3: 
# In the "World Map Choropleth", 
# when you are creating the layout, 
# ensure that your projection line is 
# = {'type':'mercator'} not Mercator with a capital...so like this:
# projection={'type':'mercator'}

# %%
# Data
df = pd.DataFrame(np.random.rand(100,4), columns='A B C D'.split())

# %%
df.head()
# Out:
#           A         B         C         D
# 0  0.052968  0.980554  0.026228  0.317240
# 1  0.992415  0.254071  0.253875  0.758213
# 2  0.266420  0.882787  0.933035  0.232623
# 3  0.305151  0.638807  0.751212  0.393717
# 4  0.193000  0.510241  0.159795  0.247512

# %%
df2 = pd.DataFrame({'Category':['A', 'B', 'C'], 'Values':[32,43,50]})

# %%
df2
# Out:
#   Category  Values
# 0        A      32
# 1        B      43
# 2        C      50

# %%
df.iplot()
# Out:
# <div>
#
#
#             <div id="5d1c74ed-90f3-4002-9a80-4a5dcc5fcfe2" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("5d1c74ed-90f3-4002-9a80-4a5dcc5fcfe2")) {
#                     Plotly.newPlot(
#                         '5d1c74ed-90f3-4002-9a80-4a5dcc5fcfe2',
# ...

# %%
# Scatter plot
df.iplot(kind='scatter', x='A', y='B', mode = 'markers')
# Out:
# <div>
#
#
#             <div id="f1ec5c92-45cb-4342-985f-6997d85f82d6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("f1ec5c92-45cb-4342-985f-6997d85f82d6")) {
#                     Plotly.newPlot(
#                         'f1ec5c92-45cb-4342-985f-6997d85f82d6',
# ...

# %%
# Bar plot
df2.iplot(kind='bar', x='Category', y='Values')
# Out:
# <div>
#
#
#             <div id="7da60d31-2d2e-43e9-ac4c-ab15d5018ecd" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("7da60d31-2d2e-43e9-ac4c-ab15d5018ecd")) {
#                     Plotly.newPlot(
#                         '7da60d31-2d2e-43e9-ac4c-ab15d5018ecd',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "Values", "orientation": "v", "text": "", "type": "bar", "x": ["A", "B", "C"], "y": [32, 43, 50]}],
# ...

# %%
df.sum().iplot(kind='bar')
# Out:
# <div>
#
#
#             <div id="4c1c536c-b681-4ac8-ad94-b78a76dfc73c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("4c1c536c-b681-4ac8-ad94-b78a76dfc73c")) {
#                     Plotly.newPlot(
#                         '4c1c536c-b681-4ac8-ad94-b78a76dfc73c',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "None", "orientation": "v", "text": "", "type": "bar", "x": ["A", "B", "C", "D"], "y": [52.768882737560666, 50.12816291600233, 51.64563377501478, 50.283445077132264]}],
# ...

# %%
# Box plots
df.iplot(kind='box')
# Out:
# <div>
#
#
#             <div id="8d95fc45-364a-410d-b9e3-557e75f7a657" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("8d95fc45-364a-410d-b9e3-557e75f7a657")) {
#                     Plotly.newPlot(
#                         '8d95fc45-364a-410d-b9e3-557e75f7a657',
# ...

# %%
# 3D surface plot
df3 = pd.DataFrame({'x':[1,2,3,4,5], 'y':[10,20,30,20,10], 'z':[5,4,3,2,1]})

# %%
df3
# Out:
#    x   y  z
# 0  1  10  5
# 1  2  20  4
# 2  3  30  3
# 3  4  20  2
# 4  5  10  1

# %%
df3.iplot(kind='surface', colorscale='rdylbu')
# Out:
# <div>
#
#
#             <div id="f90ec99d-cbf0-4ec3-874f-5a58167b43e4" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("f90ec99d-cbf0-4ec3-874f-5a58167b43e4")) {
#                     Plotly.newPlot(
#                         'f90ec99d-cbf0-4ec3-874f-5a58167b43e4',
# ...

# %%
# Histogram
df['A'].iplot(kind='hist',bins=25)
# Out:
# <div>
#
#
#             <div id="f8453297-1aad-46b7-8296-1b462da4d523" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("f8453297-1aad-46b7-8296-1b462da4d523")) {
#                     Plotly.newPlot(
#                         'f8453297-1aad-46b7-8296-1b462da4d523',
# ...

# %%
df.iplot(kind='hist')
# Out:
# <div>
#
#
#             <div id="27bafcd1-259a-4789-949f-3c508ea45161" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("27bafcd1-259a-4789-949f-3c508ea45161")) {
#                     Plotly.newPlot(
#                         '27bafcd1-259a-4789-949f-3c508ea45161',
# ...

# %%
# Spread plot
df[['A', 'B']].iplot(kind='spread')
# Out:
# C:\Users\Jared\anaconda3\lib\site-packages\cufflinks\plotlytools.py:849: FutureWarning:
#
# The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#
# C:\Users\Jared\anaconda3\lib\site-packages\cufflinks\plotlytools.py:850: FutureWarning:
#
# The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
# <div>
#
#
#             <div id="6cc363ce-c083-4bcf-82f8-e57f88697ecd" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("6cc363ce-c083-4bcf-82f8-e57f88697ecd")) {
#                     Plotly.newPlot(
#                         '6cc363ce-c083-4bcf-82f8-e57f88697ecd',
# ...

# %%
# Bubble Plot
df.iplot(kind='bubble', x='A', y='B', size='C')
# Out:
# <div>
#
#
#             <div id="335b5321-d1f6-4cdc-8cc8-a0b02780fe8e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("335b5321-d1f6-4cdc-8cc8-a0b02780fe8e")) {
#                     Plotly.newPlot(
#                         '335b5321-d1f6-4cdc-8cc8-a0b02780fe8e',
# ...

# %%
# Scatter Matrix
df.scatter_matrix()
# Out:
# <div>
#
#
#             <div id="4a3ba06f-80c9-4c41-a6c9-d62a3f427042" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("4a3ba06f-80c9-4c41-a6c9-d62a3f427042")) {
#                     Plotly.newPlot(
#                         '4a3ba06f-80c9-4c41-a6c9-d62a3f427042',
# ...
