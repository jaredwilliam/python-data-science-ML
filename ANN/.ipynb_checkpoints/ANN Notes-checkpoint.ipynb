# %% [markdown]
# # Introduction to Artificial Neural Networks (ANN)

# %% [markdown]
# Theory Topics:
# - Perceptron Model to Nerual Networks
# - Activation Functions
# - Cost Functions
# - Feed Forward Notworks
# - BackPropagation
#
# Coding Topics:
# - TensorFlow 2.0 Keras Syntax
# - ANN with Keras
#     - Regrssion
#     - Classification
# - Exercises for Keras ANN
# - Tensorboard Visualizations

# %% [markdown]
# ## Perceptron Model

# %% [markdown]
# To begin understand deep learning, we will build up our model abstractions:
# - Single Biological Neuron
# - Perceptron
# - Multi-layer Perceptron Model
# - Deep Learning Neural Network
#
# As we learn about more complex models, we will also introduce concepts, such as:
# - Activation Functions
# - Gradient Descent
# - BackPropagation
#
# Let's start with understanding how biological neurons work.

# %%
from IPython.display import Image

# %%
Image(filename='bio_neuron.PNG')

# %% [markdown]
# The main thing to see here is that there is a nucleus, a cell body, inputs, and outputs. We are going to really simplify it.
